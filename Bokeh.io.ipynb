# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c58ec0e8-c935-4772-81fd-a7c23d45b835">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file("test.html")

# %%
p = figure(title = "Test Flower")
p.xaxis.axis_label = 'X-axis'
p.yaxis.axis_label = 'Y=axis'
p.scatter(flowers['sepal_length'],flowers['sepal_width'],fill_color='green',size=10)
show(p)
# Out:
#   <div id="ca3240ce-c020-4560-b047-3155dff93a00" data-root-id="p1781" style="display: contents;"></div>

# %%
x = [2,3,4,5,6]
y = [8,7,4,5,1]
output_file('index.html')
q = figure(title = "Index")
q.xaxis.axis_label = 'X-axis'
q.yaxis.axis_label = 'Y=axis'
q.scatter(x,y)
show(q)
# Out:
#   <div id="c7761859-430a-4f0d-b7d4-dc839c54cd6e" data-root-id="p1647" style="display: contents;"></div>

# %%
import pandas as pd

# %%
df = pd.read_csv("Titanic2.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.drop('PassengerId',axis=1,inplace=True)
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                              Kelly, Mr. James    male
# 1           1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           0       2                     Myles, Mr. Thomas Francis    male
# 3           0       3                              Wirz, Mr. Albert    male
# 4           1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..        ...     ...                                           ...     ...
# 413         0       3                            Spector, Mr. Woolf    male
# 414         1       1                  Oliva y Ocana, Dona. Fermina  female
# 415         0       3                  Saether, Mr. Simon Sivertsen    male
# 416         0       3                           Ware, Mr. Frederick    male
# 417         0       3                      Peter, Master. Michael J    male
#
# ...

# %%
df.set_index("Name",inplace=True)
df
# Out:
#                                               Survived  Pclass     Sex   Age  \
# Name
# Kelly, Mr. James                                     0       3    male  34.5
# Wilkes, Mrs. James (Ellen Needs)                     1       3  female  47.0
# Myles, Mr. Thomas Francis                            0       2    male  62.0
# Wirz, Mr. Albert                                     0       3    male  27.0
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1       3  female  22.0
# ...                                                ...     ...     ...   ...
# Spector, Mr. Woolf                                   0       3    male   NaN
# Oliva y Ocana, Dona. Fermina                         1       1  female  39.0
# Saether, Mr. Simon Sivertsen                         0       3    male  38.5
# Ware, Mr. Frederick                                  0       3    male   NaN
# Peter, Master. Michael J                             0       3    male   NaN
#
# ...

# %%
df.reset_index()
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                                Kelly, Mr. James         0       3    male
# 1                Wilkes, Mrs. James (Ellen Needs)         1       3  female
# 2                       Myles, Mr. Thomas Francis         0       2    male
# 3                                Wirz, Mr. Albert         0       3    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1       3  female
# ..                                            ...       ...     ...     ...
# 413                            Spector, Mr. Woolf         0       3    male
# 414                  Oliva y Ocana, Dona. Fermina         1       1  female
# 415                  Saether, Mr. Simon Sivertsen         0       3    male
# 416                           Ware, Mr. Frederick         0       3    male
# 417                      Peter, Master. Michael J         0       3    male
#
# ...

# %%
d = {
    'key1': [1,2,3,4],
    'key2': [5,6,7,8],
    'key3': [9,10,11,12]
}
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
d2 = {
    'key4': [1,2,3,4],
    'key5': [5,6,7,8],
    'key6': [9,10,11,12]
}
pd.DataFrame(d2)
# Out:
#    key4  key5  key6
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
g = df.groupby('Pclass')
g

# %%
g.add()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 g.add()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'add'
